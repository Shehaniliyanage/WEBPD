# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('parkinsons2.csv')

# %%
df.head()
# Out:
#   Participant code  Age Gender  \
# 0             PD01   58      F
# 1             PD02   68      F
# 2             PD03   68      M
# 3             PD04   75      M
# 4             PD05   61      M
#
#    Positive history of Parkinson disease in family  Speech Changes  \
# 0                                                0               0
# 1                                                0               1
# 2                                                0               0
# 3                                                0               0
# 4                                                1               1
#
#     Facial Expressions changes  Tremor at Rest - head  Tremor at Rest - RUE  \
# 0                            1                      0                     0
# 1                            1                      0                     0
# 2                            1                      0                     0
# 3                            1                      0                     1
# 4                            1                      1                     1
#
#     Tremor at Rest - LUE   Tremor at Rest - RLE  Tremor at Rest - LLE  \
# 0                      1                      0                     1
# 1                      0                      0                     0
# 2                      0                      0                     0
# 3                      0                      1                     0
# 4                      1                      1                     0
#
#     Action or Postural Tremor - RUE   Action or Postural Tremor - LUE  \
# 0                                 0                                 0
# 1                                 1                                 1
# 2                                 0                                 0
# 3                                 1                                 1
# 4                                 1                                 1
#
#     Rigidity - neck   Rigidity - RUE   Rigidity - LUE   Rigidity - RLE  \
# 0                 0                0                1                0
# 1                 1                0                1                1
# 2                 1                0                0                1
# 3                 1                1                1                1
# 4                 1                1                1                1
#
#     Rigidity - LLE  Finger Taps - RUE  Finger Taps - LUE  \
# 0                0                  0                  1
# 1                1                  1                  1
# 2                1                  1                  1
# 3                1                  1                  1
# 4                1                  1                  1
#
#     Hand Movements  - RUE   Hand Movements  - LUE  \
# 0                       0                       0
# 1                       0                       1
# 2                       0                       1
# 3                       1                       1
# 4                       1                       1
#
#     Rapid Alternating Movements - RUE   Rapid Alternating Movements -  LUE  \
# 0                                   0                                    1
# 1                                   1                                    1
# 2                                   0                                    0
# 3                                   1                                    1
# 4                                   1                                    1
#
#     Leg Agility - RLE   Leg Agility - LLE  Arising from Chair   Posture  \
# 0                   0                   0                    0        0
# 1                   1                   1                    0        1
# 2                   1                   1                    0        1
# 3                   1                   0                    0        1
# 4                   1                   1                    1        1
#
#     Gait   Postural Stability  Body Bradykinesia and Hypokinesia   Status
# 0      0                    0                                   0       0
# 1      0                    1                                   1       1
# 2      0                    0                                   1       1
# 3      1                    0                                   1       1
# 4      1                    1                                   1       1

# %%
df.columns
# Out:
# Index(['Participant code', 'Age', 'Gender',
#        'Positive history of Parkinson disease in family', 'Speech Changes',
#        ' Facial Expressions changes', 'Tremor at Rest - head',
#        'Tremor at Rest - RUE', ' Tremor at Rest - LUE',
#        ' Tremor at Rest - RLE', 'Tremor at Rest - LLE',
#        ' Action or Postural Tremor - RUE', ' Action or Postural Tremor - LUE',
#        ' Rigidity - neck', ' Rigidity - RUE', ' Rigidity - LUE',
#        ' Rigidity - RLE', ' Rigidity - LLE', 'Finger Taps - RUE',
#        'Finger Taps - LUE', ' Hand Movements  - RUE', ' Hand Movements  - LUE',
#        ' Rapid Alternating Movements - RUE',
#        ' Rapid Alternating Movements -  LUE', ' Leg Agility - RLE',
#        ' Leg Agility - LLE', 'Arising from Chair ', 'Posture', ' Gait',
#        ' Postural Stability', 'Body Bradykinesia and Hypokinesia ', 'Status'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age  Positive history of Parkinson disease in family  \
# count  160.000000                                        160.00000
# mean    64.925000                                          0.03750
# std      9.715157                                          0.19058
# min     34.000000                                          0.00000
# 25%     60.000000                                          0.00000
# 50%     67.000000                                          0.00000
# 75%     72.000000                                          0.00000
# max     83.000000                                          1.00000
#
#        Speech Changes   Facial Expressions changes  Tremor at Rest - head  \
# count      160.000000                   160.000000             160.000000
# mean         0.200000                     0.537500               0.187500
# std          0.401256                     0.500157               0.391538
# min          0.000000                     0.000000               0.000000
# 25%          0.000000                     0.000000               0.000000
# 50%          0.000000                     1.000000               0.000000
# 75%          0.000000                     1.000000               0.000000
# max          1.000000                     1.000000               1.000000
#
#        Tremor at Rest - RUE   Tremor at Rest - LUE   Tremor at Rest - RLE  \
# count            160.000000             160.000000              160.00000
# mean               0.225000               0.075000                0.03750
# std                0.418893               0.264218                0.19058
# min                0.000000               0.000000                0.00000
# 25%                0.000000               0.000000                0.00000
# 50%                0.000000               0.000000                0.00000
# 75%                0.000000               0.000000                0.00000
# max                1.000000               1.000000                1.00000
#
#        Tremor at Rest - LLE   Action or Postural Tremor - RUE  \
# count            160.000000                        160.000000
# mean               0.062500                          0.525000
# std                0.242821                          0.500943
# min                0.000000                          0.000000
# 25%                0.000000                          0.000000
# 50%                0.000000                          1.000000
# 75%                0.000000                          1.000000
# max                1.000000                          1.000000
#
#         Action or Postural Tremor - LUE   Rigidity - neck   Rigidity - RUE  \
# count                        160.000000        160.000000       160.000000
# mean                           0.537500          0.225000         0.287500
# std                            0.500157          0.418893         0.454018
# min                            0.000000          0.000000         0.000000
# 25%                            0.000000          0.000000         0.000000
# 50%                            1.000000          0.000000         0.000000
# 75%                            1.000000          0.000000         1.000000
# max                            1.000000          1.000000         1.000000
#
#         Rigidity - LUE   Rigidity - RLE   Rigidity - LLE  Finger Taps - RUE  \
# count       160.000000       160.000000       160.000000         160.000000
# mean          0.237500         0.162500         0.125000           0.462500
# std           0.426887         0.370067         0.331757           0.500157
# min           0.000000         0.000000         0.000000           0.000000
# 25%           0.000000         0.000000         0.000000           0.000000
# 50%           0.000000         0.000000         0.000000           0.000000
# 75%           0.000000         0.000000         0.000000           1.000000
# max           1.000000         1.000000         1.000000           1.000000
#
#        Finger Taps - LUE   Hand Movements  - RUE   Hand Movements  - LUE  \
# count         160.000000              160.000000              160.000000
# mean            0.493750                0.375000                0.450000
# std             0.501531                0.523053                0.499056
# min             0.000000                0.000000                0.000000
# 25%             0.000000                0.000000                0.000000
# 50%             0.000000                0.000000                0.000000
# 75%             1.000000                1.000000                1.000000
# max             1.000000                3.000000                1.000000
#
#         Rapid Alternating Movements - RUE  \
# count                          160.000000
# mean                             0.287500
# std                              0.454018
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
#         Rapid Alternating Movements -  LUE   Leg Agility - RLE  \
# count                           160.000000          160.000000
# mean                              0.450000            0.287500
# std                               0.499056            0.454018
# min                               0.000000            0.000000
# 25%                               0.000000            0.000000
# 50%                               0.000000            0.000000
# 75%                               1.000000            1.000000
# max                               1.000000            1.000000
#
#         Leg Agility - LLE  Arising from Chair      Posture        Gait  \
# count          160.000000           160.000000  160.000000  160.000000
# mean             0.362500             0.137500    0.450000    0.362500
# std              0.482231             0.345456    0.499056    0.482231
# min              0.000000             0.000000    0.000000    0.000000
# 25%              0.000000             0.000000    0.000000    0.000000
# 50%              0.000000             0.000000    0.000000    0.000000
# 75%              1.000000             0.000000    1.000000    1.000000
# max              1.000000             1.000000    1.000000    1.000000
#
#         Postural Stability  Body Bradykinesia and Hypokinesia       Status
# count           160.000000                          160.000000  160.000000
# mean              0.250000                            0.287500    0.518750
# std               0.434372                            0.454018    0.501217
# min               0.000000                            0.000000    0.000000
# 25%               0.000000                            0.000000    0.000000
# 50%               0.000000                            0.000000    1.000000
# 75%               0.250000                            1.000000    1.000000
# max               1.000000                            1.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 32 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Participant code                                 160 non-null    object
#  1   Age                                              160 non-null    int64
#  2   Gender                                           160 non-null    object
#  3   Positive history of Parkinson disease in family  160 non-null    int64
#  4   Speech Changes                                   160 non-null    int64
#  5    Facial Expressions changes                      160 non-null    int64
#  6   Tremor at Rest - head                            160 non-null    int64
#  7   Tremor at Rest - RUE                             160 non-null    int64
#  8    Tremor at Rest - LUE                            160 non-null    int64
#  9    Tremor at Rest - RLE                            160 non-null    int64
#  10  Tremor at Rest - LLE                             160 non-null    int64
#  11   Action or Postural Tremor - RUE                 160 non-null    int64
#  12   Action or Postural Tremor - LUE                 160 non-null    int64
#  13   Rigidity - neck                                 160 non-null    int64
#  14   Rigidity - RUE                                  160 non-null    int64
#  15   Rigidity - LUE                                  160 non-null    int64
#  16   Rigidity - RLE                                  160 non-null    int64
#  17   Rigidity - LLE                                  160 non-null    int64
#  18  Finger Taps - RUE                                160 non-null    int64
#  19  Finger Taps - LUE                                160 non-null    int64
#  20   Hand Movements  - RUE                           160 non-null    int64
#  21   Hand Movements  - LUE                           160 non-null    int64
#  22   Rapid Alternating Movements - RUE               160 non-null    int64
#  23   Rapid Alternating Movements -  LUE              160 non-null    int64
#  24   Leg Agility - RLE                               160 non-null    int64
#  25   Leg Agility - LLE                               160 non-null    int64
#  26  Arising from Chair                               160 non-null    int64
#  27  Posture                                          160 non-null    int64
#  28   Gait                                            160 non-null    int64
#  29   Postural Stability                              160 non-null    int64
#  30  Body Bradykinesia and Hypokinesia                160 non-null    int64
#  31  Status                                           160 non-null    int64
# dtypes: int64(30), object(2)
# memory usage: 40.1+ KB

# %%
df.isnull().sum()
# Out:
# Participant code                                   0
# Age                                                0
# Gender                                             0
# Positive history of Parkinson disease in family    0
# Speech Changes                                     0
#  Facial Expressions changes                        0
# Tremor at Rest - head                              0
# Tremor at Rest - RUE                               0
#  Tremor at Rest - LUE                              0
#  Tremor at Rest - RLE                              0
# Tremor at Rest - LLE                               0
#  Action or Postural Tremor - RUE                   0
#  Action or Postural Tremor - LUE                   0
#  Rigidity - neck                                   0
#  Rigidity - RUE                                    0
#  Rigidity - LUE                                    0
#  Rigidity - RLE                                    0
#  Rigidity - LLE                                    0
# Finger Taps - RUE                                  0
# Finger Taps - LUE                                  0
#  Hand Movements  - RUE                             0
#  Hand Movements  - LUE                             0
#  Rapid Alternating Movements - RUE                 0
#  Rapid Alternating Movements -  LUE                0
#  Leg Agility - RLE                                 0
#  Leg Agility - LLE                                 0
# Arising from Chair                                 0
# Posture                                            0
#  Gait                                              0
#  Postural Stability                                0
# Body Bradykinesia and Hypokinesia                  0
# Status                                             0
# dtype: int64

# %%
df.shape
# Out:
# (160, 32)

# %%
df['Status'].value_counts()
# Out:
# 1    83
# 0    77
# Name: Status, dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Status'])
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
df.dtypes
# Out:
# Participant code                                   object
# Age                                                 int64
# Gender                                             object
# Positive history of Parkinson disease in family     int64
# Speech Changes                                      int64
#  Facial Expressions changes                         int64
# Tremor at Rest - head                               int64
# Tremor at Rest - RUE                                int64
#  Tremor at Rest - LUE                               int64
#  Tremor at Rest - RLE                               int64
# Tremor at Rest - LLE                                int64
#  Action or Postural Tremor - RUE                    int64
#  Action or Postural Tremor - LUE                    int64
#  Rigidity - neck                                    int64
#  Rigidity - RUE                                     int64
#  Rigidity - LUE                                     int64
#  Rigidity - RLE                                     int64
#  Rigidity - LLE                                     int64
# Finger Taps - RUE                                   int64
# Finger Taps - LUE                                   int64
#  Hand Movements  - RUE                              int64
#  Hand Movements  - LUE                              int64
#  Rapid Alternating Movements - RUE                  int64
#  Rapid Alternating Movements -  LUE                 int64
#  Leg Agility - RLE                                  int64
#  Leg Agility - LLE                                  int64
# Arising from Chair                                  int64
# Posture                                             int64
#  Gait                                               int64
#  Postural Stability                                 int64
# Body Bradykinesia and Hypokinesia                   int64
# Status                                              int64
# dtype: object

# %%
X = df.drop(['Participant code'], 1)
X = X.drop(['Status'], 1)
X = X.drop(['Gender'], 1)
y = df['Status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from xgboost import XGBClassifier
model = XGBClassifier().fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, f1_score

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.875

# %%
f1_score(y_test, predictions)
# Out:
# 0.8571428571428571

# %%
import pickle
# Writing different model files to file
with open( 'modelForPrediction.sav', 'wb') as f:
    pickle.dump(model,f)
    
with open('standardScalar.sav', 'wb') as f:
    pickle.dump(sc,f)
